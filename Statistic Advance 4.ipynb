# %% [markdown]
# ## statistics Advance 4

# %% [markdown]
# ### Question 1
#
# Q1: What is the difference between a t-test and a z-test? Provide an example scenario where you would
# use each type of test.
#
# __Answer__
#
# 1. t-tests are used when the population variance is unknown and the sample size is small, while z-tests are used when the population variance is known and the sample size is large.
#
# 2. T-tests use the Student’s t-distribution while z-tests use the normal distribution.
#
# 3. Degrees of freedom are needed in t-testing, not in z-testing. The z statistic is calculated with the standard error while the t statistic uses the estimated standard error.
#
# __Example of where to use them__
#
# __T-Test__
#
# An example scenario where a t-test would be used is if a researcher wants to compare the mean weight of two different groups of mice. One group has a sample size of 25 and the other group has a sample size of 50. Since one of the groups has a sample size less than 30, a t-test would be appropriate.
# Note: The decision will be opposite if population variance/standard deviation was given
#
# __Z-Test__
#
# An example scenario where a z-test would be used is if a researcher wants to compare the proportion of males and females who prefer a certain brand of soda. The researcher collects data from a random sample of 1000 males and 1000 females. Since the sample sizes are large and the population variance can be estimated from the sample data, a z-test would be appropriate

# %% [markdown]
# ### Question 2
# Q2: Differentiate between one-tailed and two-tailed tests.
#
# A one-tailed test is a statistical test in which the critical region (the region where we reject the null hypothesis) is entirely contained within one tail of the sampling distribution. This type of test is used when the alternative hypothesis specifies a direction (e.g., greater than or less than). For example, if we want to test whether a new drug lowers blood pressure, we would use a one-tailed test with the critical region in the left tail of the sampling distribution.
#
# ![image.png](attachment:image.png)
#
# A two-tailed test is a statistical test in which the critical region is split between the two tails of the sampling distribution. This type of test is used when the alternative hypothesis does not specify a direction. For example, if we want to test whether a new drug has any effect on blood pressure (either lowering or raising it), we would use a two-tailed test with critical regions in both tails of the sampling distribution.
#
# ![image-2.png](attachment:image-2.png)
#
# __In General__
#
# The main difference between one-tailed and two-tailed tests is the directionality of the alternative hypothesis and the location of the critical region(s).

# %% [markdown]
# ### Question 3
#
# Q3: Explain the concept of Type 1 and Type 2 errors in hypothesis testing. Provide an example scenario for
# each type of error.
#
#
# __Type 1 error__
#
# Type 1 error occurs when the null hypothesis is rejected when it is actually true. This means that we conclude that there is a significant effect when in reality there is no effect. In addition, the probability of making a Type 1 error is denoted by the Greek letter alpha (α) and is also known as the significance level.
#
# For example, if a researcher conducts a study to test whether a new drug is effective in treating a disease and concludes that the drug is effective when it is actually not, then a Type 1 error has occurred.
#
#
# __Type 2 error__
#
# A Type 2 error occurs when the null hypothesis is not rejected when it is actually false. This means that we conclude that there is no significant effect when in reality there is an effect. The probability of making a Type 2 error is denoted by the Greek letter beta (β).
#
# For example, if a researcher conducts a study to test whether a new drug is effective in treating a disease and concludes that the drug is not effective when it actually is, then a Type 2 error has occurred.
#
# __In general__
#
# In summary, a Type 1 error is a false positive and a Type 2 error is a false negative.

# %% [markdown]
# ### Question 4
#
# Q4: Explain Bayes's theorem with an example.
#
#
#
# QBayes’ theorem is a mathematical formula that describes the relationship between two events and their probabilities. It is used to calculate the probability of an event occurring based on prior knowledge or evidence. The formula for Bayes’ theorem is:
#
# P(A|B) = (P(B|A) * P(A)) / P(B)
#
# where P(A|B) is the probability of event A occurring given that event B has occurred, P(B|A) is the probability of event B occurring given that event A has occurred, P(A) is the prior probability of event A occurring, and P(B) is the total probability of event B occurring.
#
# __Example__
#
# To calculate the probability that a person has a certain disease given that they have tested positive for it before. Let’s say that the prevalence of the disease in the population is 0.1% (i.e., P(Disease) = 0.001), the sensitivity of the test (i.e., the probability of testing positive given that the person has the disease) is 99% (i.e., P(Positive|Disease) = 0.99), and the specificity of the test (i.e., the probability of testing negative given that the person does not have the disease) is 95% (i.e., P(Negative|No Disease) = 0.95).
#
# Using Bayes’ theorem, we can calculate the probability that a person has the disease given that they have tested positive as follows:
#
# P(Disease|Positive) = (P(Positive|Disease) * P(Disease)) / P(Positive) = (0.99 * 0.001) / ((0.99 * 0.001) + (1 - 0.95) * (1 - 0.001)) ≈ 0.02
#
# So, even though the person has tested positive for the disease, there is only about a 2% chance that they actually have it.

# %% [markdown]
# ### Question 5
#
# Q5: What is a confidence interval? How to calculate the confidence interval, explain with an example.
#
# __Answer_
#
# Confidence interval is a range of values that is likely to contain the true value of a population parameter with a certain level of confidence. It is calculated from a sample of data and provides an estimate of the range in which the true population parameter is likely to lie.
#
# The formula for calculating a confidence interval for a population mean depends on whether the population standard deviation is known or not. If the population standard deviation is known, then the formula for a confidence interval for the population mean is:
#
# sample mean +/- (critical value) * (population standard deviation / sqrt(sample size))
#
# If the population standard deviation is not known, then the formula for a confidence interval for the population mean is:
#
# sample mean +/- (critical value) * (sample standard deviation / sqrt(sample size))
#
# Thus, critical value is determined by the confidence level and can be found using a z-table or t-table depending on whether the population standard deviation is known or not.
#
#
# __Example__
#
# Suppose we have a random sample of 100 people and we want to estimate their average height with 95% confidence. The sample mean height is 170 cm and the sample standard deviation is 10 cm. Since the population standard deviation is not known, we use the formula for a confidence interval when the population standard deviation is not known:
#
# 170 +/- (1.96) * (10 / sqrt(100)) = (168.04, 171.96)
#
# So, we are 95% confident that the true average height of the population lies between 168.04 cm and 171.96 cm.

# %% [markdown]
# ### Question 6
#
# Q6. Use Bayes' Theorem to calculate the probability of an event occurring given prior knowledge of the
# event's probability and new evidence. Provide a sample problem and solution.
#
# __Answer__
#
# Suppose a factory produces light bulbs and 1% of the light bulbs are defective (i.e., P(Defective) = 0.01). The factory uses a machine to test the light bulbs and the machine correctly identifies 99% of the defective light bulbs (i.e., P(Pass|Defective) = 0.01) and 95% of the non-defective light bulbs (i.e., P(Pass|Non-Defective) = 0.95).
#
# Using Bayes’ theorem, we can calculate the probability that a light bulb is defective given that it passed the test as follows:
#
# P(Defective|Pass) = (P(Pass|Defective) * P(Defective)) / P(Pass) = (0.01 * 0.01) / ((0.01 * 0.01) + (0.95 * 0.99)) ≈ 0.000106
#
# So, even though a light bulb passed the test, there is only about a 0.01% chance that it is actually defective.

# %% [markdown]
# ### Question 7
#
# Q7. Calculate the 95% confidence interval for a sample of data with a mean of 50 and a standard deviation
# of 5. Interpret the results.
#
# __Anwser:__
#
# In this scenario, we T table for the critical values are not given population standard deviation , so we use this below formula:
#
# alpha = 95%
#
# Confidence Interval = sample mean +/- (critical value) * (sample standard deviation / sqrt(sample size))
#
# alpha = 100 - 95 = 5/2 = 2.5/100 = 0.025
#
# ** check 0.9750 on the z table
# z = 1 - 0.025 = 0.9750 ==> 1.96
#
# lower_bound = 50 - (1.96/(5/√sample_size))
# upper_bound = 50 + (1.96/(5/√sample_size))
#
# It is not possible to calculate confidence interval without sample size, but base on central limit theorem with increase in size the width of the confidence interval will shrink making the calculation more precise. On a general note, base on the information provided we can not determine the confidence interval, however, the above formula holds.

# %% [markdown]
# ### Question 8
#
# Q8 What is the margin of error in a confidence interval? How does sample size affect the margin of error?
# Provide an example of a scenario where a larger sample size would result in a smaller margin of error.
#
# __Answer__
#
# The margin of error is a measure of the precision of a confidence interval. It is equal to half the width of the entire confidence interval and represents the maximum amount by which the sample estimate is expected to differ from the true population parameter.
#
# As I explianed in question 7, the sample size affects the margin of error because as the sample size increases, the standard error of the mean decreases. Resulting in margin of error decreasing as the sample size increases, resulting in a more precise estimate of the population parameter.
#
# __Example__
#
# Here’s an example to illustrate how a larger sample size would result in a smaller margin of error: Suppose we want to estimate the average height of a population with 95% confidence. We collect a random sample of 100 people and find that their average height is 170 cm with a standard deviation of 10 cm. The margin of error for this estimate would be approximately 1.96 * (10 / sqrt(100)) = 1.96.
#
# Now suppose we collect a larger sample of 1000 people and find that their average height is also 170 cm with a standard deviation of 10 cm. The margin of error for this estimate would be approximately 1.96 * (10 / sqrt(1000)) = 0.62.
#
# In conclusion, the larger sample size results in a smaller margin of error, indicating that our estimate is more precise.

# %% [markdown]
# ### Question 9
#
# Q9. Calculate the z-score for a data point with a value of 75, a population mean of 70, and a population
# standard deviation of 5. Interpret the results.
#
#
# __Answer__
#
# Xi = 75
# µ = 70
# δ = 5
#
# z_statistic = (75-70)/5
# z_statistic = 1
#
# So, the z-score for a data point with a value of 75 is 1. This means that the data point is 1 standard deviation above the population mean. A z-score of 1 is considered to be relatively common and falls within the range of what is considered to be a typical value for a data point from this population.

# %% [markdown]
# ### Question 10
#
# Q10. In a study of the effectiveness of a new weight loss drug, a sample of 50 participants lost an average
# of 6 pounds with a standard deviation of 2.5 pounds. Conduct a hypothesis test to determine if the drug is
# significantly effective at a 95% confidence level using a t-test.
#
# __Answer__
#
# H0: The new drug is not significant at 95% : µ = 0
# Ha: The new drug is significant at 95%:   µ != 0
#
# ![image.png](attachment:image.png)
#
# we are using t-test (2 tails)
#
# t_statistics = (sample mean - population mean) / (sample standard deviation / sqrt(sample size))
#
# t_statistics = (6-0)/(2.5/√(50))

# %%
## code to solve this using the formular
def onetail_ttest(population_mean, sample_size, sample_mean, sample_std):
    import math  ## for sqrt
       
    ## t value calculated
    t_cal = (sample_mean-population_mean)/(sample_std/math.sqrt(sample_size))   
    return t_cal 

t_statistics = onetail_ttest(0, 50, 6, 2.5)
# print(t_statistics)
print(f"T_statistics: {t_statistics}\n")

def t_tabulated(df, alpha):
    from scipy.stats import t
    
    # degrees of freedom
        
    # one-tailed critical value
    critical_value = t.ppf(alpha, df)
    
    return critical_value

critical_value = t_tabulated(49, 0.95)

print(f"Critical Value: {critical_value}\n")

if t_statistics > critical_value:
    print("Reject the null hypothesis")
    print('''
    Since our calculated test statistic is greater than the critical value, 
    we reject the null hypothesis and conclude that there is significant 
    evidence at the 95% confidence level to suggest that the weight loss drug 
    is effective.
    ''')
else:
    print("Fail to reject the null hypothesis")
# Out:
# T_statistics: 16.970562748477143
#
# Critical Value: 1.6765508919142629
#
# Reject the null hypothesis
#
#     Since our calculated test statistic is greater than the critical value,
#     we reject the null hypothesis and conclude that there is significant
#     evidence at the 95% confidence level to suggest that the weight loss drug
#     is effective.

# %% [markdown]
# ### Question 11
#
# Q11. In a survey of 500 people, 65% reported being satisfied with their current job. Calculate the 95%
# confidence interval for the true proportion of people who are satisfied with their job.
#
#
# __Answer__
#
# Note: we use Z table to obtain the critical  value
#
# We use the use the formula for confidence interval using proportion:
#
# p̂ ± z√(p̂(1-p̂)/n),
# where
# p̂ is the sample proportion,
# n is the sample size
# z is the critical value for the desired level of confidence.
#
# In this case, p̂ = 0.65, n = 500, and z* = 1.96 (for a 95% confidence level). Plugging these values into the formula gives us:

# %%
###  import needed library

import math


# standard_error = (math.sqrt((0.65(1-0.65)/500)))
# standard_error


lower_bound = 0.65 - 1.96*(math.sqrt((0.65*(1-0.65))/500))
upper_bound = 0.65 + 1.96*(math.sqrt((0.65*(1-0.65))/500))

print(f"Confidence interval lies between: {round(lower_bound,2)*100}%, {round(upper_bound,2)*100}%")

#So the 95% confidence interval for the true proportion 
#of people who are satisfied with their job is (0.6103, 0.6897).
# Out:
# Confidence interval: 61.0%, 69.0%

# %% [markdown]
# ### Question 12
#
# Q12. A researcher is testing the effectiveness of two different teaching methods on student performance.
# Sample A has a mean score of 85 with a standard deviation of 6, while sample B has a mean score of 82
# with a standard deviation of 5. Conduct a hypothesis test to determine if the two teaching methods have a
# significant difference in student performance using a t-test with a significance level of 0.01.
#
# __Answer__
#
# Hypothesis:
# H0: No significant difference between the two sample means. xbarA = xbarB
# H1: Significant difference between the two sample means. xbarA != xbarB
#
#
# Analysis type : Two Sample t-test
#
# formula:
#
# t = (x̄1 - x̄2) / √((s1^2/n1) + (s2^2/n2))
#
# where:
#
# x̄1 and x̄2 are the sample means
#
# s1 and s2 are the sample standard deviations
#
# n1 and n2 are the sample sizes
#
# Note: Both sample means were not given, without sample mean we can not do this calculation.
#
# Let's assume a that the sample sizes are equal (n1 = n2), we can calculate the test statistic as:
#
# t = (85 - 82) / √((6^2/n) + (5^2/n))
#
# critical value = check up significance (0.01) on two-tailed t-table
#
# Without knowing the sample sizes (n1 and n2), we cannot calculate the exact value of the test statistic or determine the degrees of freedom for the t-distribution. Therefore, we cannot complete the hypothesis test.

# %% [markdown]
# ### Question 13
#
# Q13. A population has a mean of 60 and a standard deviation of 8. A sample of 50 observations has a mean of 65. Calculate the 90% confidence interval for the true population mean.
#
# __Answer__
#
# Z table will be used to get the critical value using the significant
# significant  = 100 - 90 = 10/2 = 5% = 0.05
# z-table check = 1-0.05 = 0.95 (check on ztable) = 1.65
#
# ![image.png](attachment:image.png)
#
# formular:
#
# confidence interval = sm ± CV * (std/√(Ss))
#
# where:
#
# sm ==Sample  mean
# Ss== Sample size
# std == standard deviation
# CV == critical  value

# %%
import math

ci_lower = 65 - 1.65 * (8/math.sqrt(50))
ci_upper = 65 + 1.65 * (8/math.sqrt(50))
print(ci_lower, ci_upper)
# Out:
# 63.133238097667515 66.86676190233248

# %% [markdown]
# ### Question 13
#
# Q14. In a study of the effects of caffeine on reaction time, a sample of 30 participants had an average reaction time of 0.25 seconds with a standard deviation of 0.05 seconds. Conduct a hypothesis test to
# determine if the caffeine has a significant effect on reaction time at a 90% confidence level using a t-test.
#
# __Answer__
#
# H0: The caffeine has no significant effect on reaction time. µ = 0
# Ha: The caffeine has significant effect on reaction time. µ != 0
#
# significance level = 90%
#
# Two table will be use to calculate the critical value, since no population standard deviation
#
# t_statistics = (xbar - µ)/(std/√n)
#
# Where:
# xbar = Sample mean
# µ = True mean (population mean)
# std = Standard deviation
# n = Sample mean
#
# Significant = 100 - 90 = 10/2 = 5% = 0.05
#
# critical value = df, sig (check this up on t-table )
#
# critical value  = 2.0452

# %%
import math

critical_value  = 2.0452
t_statistics = (0.25-0)/(0.05/math.sqrt(30))
print(f"Critical values: {critical_value}")
print(f"T-Statistics: {t_statistics}\n")

if t_statistics < (-critical_value) or t_statistics > critical_value:
    print("Reject null hypothesis")
else:
    print("Fail to reject the null hypothesis")
# Out:
# Critical values: 2.0452
# T-Statistics: 27.386127875258307
#
# Reject null hypothesis

# %% [markdown]
# ### The End
